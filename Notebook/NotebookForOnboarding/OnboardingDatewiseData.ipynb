# %% [markdown]
# # <div align="center" style="color: #ff5733;">Demographic Data</div>

# %% [markdown]
# # Demographic Data

# %%
# %% [markdown]
# # Jupyter Notebook Loading Header
#
# This is a custom loading header for Jupyter Notebooks in Visual Studio Code.
# It includes common imports and settings to get you started quickly.

# %% [markdown]
## Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.cloud import bigquery
import os
path = r'C:\Users\DwaipayanChakroborti\AppData\Roaming\gcloud\legacy_credentials\dchakroborti@tonikbank.com\adc.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = path
client = bigquery.Client(project='prj-prod-dataplatform')

# %% [markdown]
## Configure Settings
# Set options or configurations as needed
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Function to get the date range

# %%
import datetime
from google.cloud import bigquery

def get_date_range(start_date, end_date):
    for n in range(int((end_date - start_date).days)):
        yield start_date + datetime.timedelta(n)

# %% [markdown]
# # Function to identify the customer and the onboarding date on a particular date

# %%
def CustomerIdentify(date):
    sq = f"""select distinct cust_id, created_dt onboardingDate FROM `dl_customers_db_raw.tdbk_customer_mtb` WHERE 1=1 and date(created_dt) = "{date}" and cust_id is not null; """
    df = client.query(sq).to_dataframe()
    return df

# %% [markdown]
# # Function to calculate the Age of customer

# %%
def calculate_age_in_days(date_of_birth):
    from datetime import datetime
    # Parse the date of birth
    dob = datetime.strptime(date_of_birth, "%d %b %Y")

    # Get the current date
    current_date = datetime.now()

    # Calculate the difference
    age_days = (current_date - dob).days

    return age_days

def add_age_column(df, date_column='dateOfBirth', new_column='AgeInDays'):
    # Apply the calculate_age_in_days function to the date column
    df[new_column] = df[date_column].apply(calculate_age_in_days)
    return df

# %% [markdown]
# # Function to run the demographic Data preparation query

# %%
def demographicdata(a, b, df):
    # Education Type
    # print("Education Type")
    sq = f"""
    with
    educate as 
    (select distinct edu.digitalLoanAccountId, edu.education_id, edu1.description
    from `prj-prod-dataplatform.dl_loans_db_raw.tdbk_loan_purpose` edu
    inner join (select id, description from dl_loans_db_raw.tdbk_loan_lov_mtb where module = 'Education') edu1 on edu.education_id = edu1.id
    ),
    educate2 as 
    (select *, row_number() over(partition by digitalLoanAccountId order by education_id desc) rnk from educate),
    educate3 as 
    (select * from educate2 where rnk = 1)
    select lmt.customerId,
    educate3.education_id,
    educate3.description Education_Type, 
    educate3.rnk educationrnk
    from educate3 
    inner join prj-prod-dataplatform.risk_credit_mis.loan_master_table lmt on lmt.digitalLoanAccountId = educate3.digitalLoanAccountId
    where lmt.customerId in {a}
    """
    educationdf = client.query(sq).to_dataframe(progress_bar_type='tqdm')
    # Telco Provider
    # print("Telco Provider")
    sq = f"""
    WITH ac_created AS 
    (
    ## Base data of onboarded users
    SELECT DISTINCT 
    product,
    CASE 
        WHEN product = 'LOAN1.0' THEN 'Borrow'
        WHEN product = 'TSA1.0' THEN 'Save'
        WHEN product = 'TSAE1.0' THEN 'Explore'
        ELSE product END type,
    cust_id,
    user_id,
    device_id,
    created_dt,
    gender,
    mobile_no,
    birthplace,
    FROM prj-prod-dataplatform.dl_customers_db_raw.tdbk_customer_mtb
    WHERE 1=1
    AND cast(cust_id as numeric) in {a}
    --AND created_dt >= '2023-06-01'
    ORDER BY 4
    )
    select 
        ac.cust_id,
        ac.user_id,
        ac.device_id,
        ac.created_dt,
        ac.gender,
        ac.birthplace,
        ac.mobile_no,
        ac.product,
        ac.type,
        t4.GeneralData.telephony_info__network_operator_name telcoProvider
    from ac_created ac
    inner join prj-prod-dataplatform.dl_loans_db_raw.tdbk_loan_customer_details tlcd on tlcd.custId = ac.cust_id  
    inner JOIN `prj-prod-dataplatform.dl_loans_db_raw.tdbk_credolab_track` t3 ON cast(tlcd.credolabRefNumber as string) = cast(t3.refno as string)
    left JOIN `prj-prod-dataplatform.credolab_raw.android_credolab_datasets_struct_columns` t4 ON t3.refno = t4.deviceId
    where cast(ac.cust_id as numeric) in {a}
    """
    clientdemodf1 = client.query(sq).to_dataframe(progress_bar_type='tqdm')
    # Merge Client Demo 1 with educationdf 
    print("Merge Client Demo 1 with educationdf ")
    df['cust_id'] = df['cust_id'].astype(np.int64)
    clientdemodf1['cust_id'] = clientdemodf1['cust_id'].astype(np.int64)
    dfmain = df.merge(clientdemodf1, on = 'cust_id', how = 'left')
    dfmain = clientdemodf1.merge(educationdf, left_on='cust_id', right_on='customerId', how = 'left')
    dfmain.drop(columns=['customerId', 'educationrnk'], inplace = True)
    # Customer Details
    # print("Customer Details")
    sq = f"""    
    SELECT 
    custid, dateOfBirth, 
    signUpAccNo, 
    kycStatus,
    addressline1, 
    city, 
    province, 
    barangay, 
    provinceCode, 
    postalcode, 
    mailingCity, 
    mailingPostalCode, 
    mailingProvince,
    natureofwork, 
    employmentstatus, 
    mobileOs, 
    docType, 
    onboardingDate, 
    created_dt, 
    ABS(TIMESTAMP_DIFF(
        PARSE_TIMESTAMP('%Y-%m-%d %H:%M:%E6S', onboardingDate),
        CAST(created_dt AS TIMESTAMP),
        MINUTE
    )) AS Minutestakentoonboard,
    companyName, 
    industry, 
    device_dtl,
    FROM 
    `prj-prod-dataplatform.dl_loans_db_raw.tdbk_loan_customer_details`
    WHERE 
    CAST(custId AS NUMERIC) IN {a}
    """
    cddf = client.query(sq).to_dataframe(progress_bar_type='tqdm')
    cddf['custid'] = cddf['custid'].astype(np.int64)
    cddf.rename(columns={'custid':'cust_id'}, inplace=True)
    dfmain = dfmain.merge(cddf, on='cust_id', how = 'left')
    dfmain.drop(columns=['created_dt_y'], inplace=True)
    dfmain.rename(columns={'created_dt_x':'created_dt'}, inplace = True)
    
    # Add AgeInYears column (approximate)
    # print("Add AgeInYears column (approximate)")
    dfmain['Age'] = dfmain['dateOfBirth'].apply(calculate_age_in_days)
    dfmain['Age'] = dfmain['Age'] //365
    
    # Region
    # print("Region")
    
    sq = f"""
    Select distinct 
    a.user_id,
    cast(a.cust_Id as numeric) cust_id,
    hm_postalcode,
    hm_barangay,
    hm_city,
    hm_province,
        CASE
        WHEN hm_province = 'KALINGA' THEN 'CAR – Cordillera Administrative Region'
        WHEN hm_province = 'OCCIDENTAL MINDORO' THEN 'MIMAROPA Region'
        WHEN hm_province = 'ORIENTAL MINDORO' THEN  'MIMAROPA Region'
        WHEN hm_province = 'ORODNIM' THEN 'MIMAROPA Region'
        WHEN hm_province = 'SAMAR (WESTERN SAMAR)' THEN 'Region VIII – Eastern Visayas'
        WHEN hm_province = 'ZAMBOANGA SIBUGAY' THEN 'Region IX – Zamboanga Peninsula'
        ELSE Region_name END Region_Name 
    FROM prj-prod-dataplatform.dl_customers_db_raw.tdbk_customer_mtb a
    LEFT JOIN prj-prod-dataplatform.dl_customers_db_raw.tdbk_customer_add_mtb f ON a.user_id = f.user_id
    LEFT JOIN prj-prod-dataplatform.dap_ds_poweruser_playground.region_mappings h ON LOWER(f.hm_province) = LOWER(h.province)
    where cast(a.cust_Id as numeric) in {a}
    ;
    """

    regiondf = client.query(sq).to_dataframe(progress_bar_type = 'tqdm')
    
    regiondf = regiondf[['cust_id', 'hm_postalcode', 'hm_barangay', 'hm_city',
       'hm_province', 'Region_Name']].copy()
    
    regiondf['cust_id'] = regiondf['cust_id'].astype(np.int64)
    dfmain = dfmain.merge(regiondf, on='cust_id', how = 'left')
    # List of columns to check and their corresponding 'hm_' columns
    # print("List of columns to check and their corresponding 'hm_' columns")
    columns_to_check = [
        ('city', 'hm_city'),
        ('province', 'hm_province'),
        ('barangay', 'hm_barangay'),
        ('postalcode', 'hm_postalcode')
    ]

    # Loop through the columns and replace null values
    # print("Loop through the columns and replace null values")
    for col, hm_col in columns_to_check:
        dfmain[col] = dfmain[col].fillna(dfmain[hm_col])
    
    dfmain.drop(columns = ['hm_postalcode', 'hm_barangay', 'hm_city',
       'hm_province'], inplace = True)
    
    # Device Location at Onboarding
    # print("Device Location at Onboarding")
    
    sq =f"""SELECT 
    customer_id, 
    CASE WHEN event_description = 'Onboarding' THEN latitude END AS Onboarding_latitude,
    CASE WHEN event_description = 'Onboarding' THEN longitude END AS Onboarding_longitude,
    CASE WHEN event_description = 'Loan Journey' THEN latitude END AS loanjourney_latitude,
    CASE WHEN event_description = 'Loan Journey' THEN longitude END AS loanjouney_longitude,
    CASE WHEN event_description = 'Apigee Logs' THEN latitude END AS ApigeeLogs_latitude,
    CASE WHEN event_description = 'Apigee Logs' THEN longitude END AS ApigeeLogs_longitude
    FROM `prj-prod-dataplatform.risk_mart.customer_gps_location`
    where cast(customer_id as numeric) in {a}
    QUALIFY ROW_NUMBER() OVER (PARTITION BY customer_id ORDER BY gps_collection_date DESC) = 1
    ;
    """

    locationdf = client.query(sq).to_dataframe(progress_bar_type = 'tqdm')
    
    locationdf = locationdf.rename(columns={'customer_id': 'cust_id'}).astype({'cust_id': np.int64})

    dfmain = dfmain.merge(locationdf, on = 'cust_id', how = 'left')
    
    # Marital Status, No. of Dependents, income
    # print("Marital Status, No. of Dependents, income")
    sq = f"""  
    select 
    customerId,
    maritalStatus,
    dependentsCount, 
    monthlyIncome,
    startApplyDateTime,
    from
    prj-prod-dataplatform.risk_credit_mis.loan_master_table
    where (maritalStatus is not null or dependentsCount is not null or monthlyIncome is not null)
    and customerId in {a}
    qualify row_number() over (partition by customerId order by startApplyDateTime desc) = 1
    ;
    """
    loandf = client.query(sq).to_dataframe(progress_bar_type = 'tqdm')
    loandf.rename(columns={'customerId':'cust_id'}, inplace = True)
    dfmain = dfmain.merge(loandf, on = 'cust_id', how = 'left')

    # Prepaid and PostPaid Flag
    
    # print("Prepaid and PostPaid Flag")
    
    sq = f"""    
    WITH ac_created AS 
    (
    ## Base data of onboarded users
    SELECT DISTINCT 
    product,
    CASE 
        WHEN product = 'LOAN1.0' THEN 'Borrow'
        WHEN product = 'TSA1.0' THEN 'Save'
        WHEN product = 'TSAE1.0' THEN 'Explore'
        ELSE product END type,
    cust_id,
    user_id,
    device_id,
    created_dt,
    gender,
    mobile_no,
    FROM prj-prod-dataplatform.dl_customers_db_raw.tdbk_customer_mtb
    WHERE 1=1
    AND cast(cust_id as numeric) in {a}
    AND created_dt >= '2023-06-01'
    ORDER BY 4
    )

    , f_loan AS 
    (
    ## First applied loan of a customer 
    SELECT DISTINCT customerId, new_loan_type, applicationStatus, disbursementdatetime, startApplydatetime
    FROM `risk_credit_mis.loan_master_table`
    WHERE 1=1
    AND customerId in {a}
    AND startApplyDatetime >= '2023-06-01'
    QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId ORDER BY startApplyDatetime ASC) =1
    )


    , deposit_balance AS 
    (
    ## Gets the balance of a customer on their 90th day upon account opening
        ## For the 1st condition of the balance of a customer upon the observation date
    SELECT DISTINCT a.ofdateopened,a.ofcustomerid, a.ofstandardaccountid,account_type,balanceDateAsOf, clearedbalance,
    FROM `prj-prod-dataplatform.core_raw.customer_accounts` a
    JOIN `risk_mart.customer_balance` b ON a.ofcustomerid = b.client_id AND a.ofstandardaccountid = b.accountid
    WHERE 1=1
    AND cast(a.ofcustomerid as numeric) in {a}
    -- AND clearedbalance >= 100
    -- AND ofcustomerid IN ('1514439','1252865','1248952')
    QUALIFY ROW_NUMBER() OVER (PARTITION BY ofcustomerid, ofstandardaccountid ORDER BY balancedateasof ASC) = 90
    )

    , af_link AS
    (
    ## To get the AF ID and Customer ID Link (using the first install of a customer)
    SELECT DISTINCT customer_user_id, appsflyer_id, media_source, partner, campaign
    FROM `appsflyer_raw.organic_in_app_events_report`
    WHERE 1=1
    and customer_user_id in {b}
    AND customer_user_id IS NOT NULL
    QUALIFY ROW_NUMBER() OVER (PARTITION BY customer_user_id ORDER BY install_time ASC) = 1
    
    UNION ALL
    
    SELECT DISTINCT customer_user_id, appsflyer_id, media_source, partner, campaign
    FROM `appsflyer_raw.in_app_events_report`
    WHERE 1=1
    and customer_user_id in {b}
    AND customer_user_id IS NOT NULL
    QUALIFY ROW_NUMBER() OVER (PARTITION BY customer_user_id ORDER BY install_time ASC) = 1
    )


    , demog_details AS 
    (
    ## Demographic Details
    SELECT DISTINCT
    a.user_id,
    a.cust_Id,
    a.device_id,
    b.id,
    c.description source_of_funds,
    d.description employment_status,
    monthly_income,
    hm_postalcode,
    hm_barangay,
    hm_city,
    hm_province,
    CASE
        WHEN hm_province = 'KALINGA' THEN 'CAR – Cordillera Administrative Region'
        WHEN hm_province = 'OCCIDENTAL MINDORO' THEN 'MIMAROPA Region'
        WHEN hm_province = 'ORIENTAL MINDORO' THEN  'MIMAROPA Region'
        WHEN hm_province = 'ORODNIM' THEN 'MIMAROPA Region'
        WHEN hm_province = 'SAMAR (WESTERN SAMAR)' THEN 'Region VIII – Eastern Visayas'
        WHEN hm_province = 'ZAMBOANGA SIBUGAY' THEN 'Region IX – Zamboanga Peninsula'
        ELSE Region_name END Region_Name
    FROM prj-prod-dataplatform.dl_customers_db_raw.tdbk_customer_mtb a
    LEFT JOIN prj-prod-dataplatform.dl_dynamo_db_raw.tdbk_regfinancial_profile1 b ON a.device_id = b.deviceId
    LEFT JOIN prj-prod-dataplatform.dl_dynamo_db_raw.tdbk_source_of_funds_mtb c ON b.sourceOfFundKey = c.id  
    LEFT JOIN prj-prod-dataplatform.dl_dynamo_db_raw.tdbk_employment_status_mtb d ON b.employmentStatusKey = d.id
    LEFT JOIN prj-prod-dataplatform.dl_customers_db_raw.tdbk_cust_profile_mtb e ON a.user_id = e.user_id
    LEFT JOIN prj-prod-dataplatform.dl_customers_db_raw.tdbk_customer_add_mtb f ON a.user_id = f.user_id
    LEFT JOIN prj-prod-dataplatform.dap_ds_poweruser_playground.region_mappings h ON LOWER(f.hm_province) = LOWER(h.province)
    where cast(a.cust_Id as numeric) in {a}
    )


    ## Base query used to connect to other features 
    SELECT DISTINCT
    a.created_dt registration_date,
    -- startApplyDateTime,
    -- ofdateopened,
    -- balancedateasof,
    a.cust_id,
    a.user_id,
    a.product,
    a.type,
    -- account_type,
    -- ofstandardaccountid,
    -- clearedbalance, 
    a.gender,
    customer_age,
    Region_Name,
    hm_province,
    hm_city,
    hm_barangay,
    hm_postalcode,
    source_of_funds,
    employment_status,
    CAST(monthly_income AS FLOAT64)*12.5 self_declared_annual_income,
    -- add the salary scale annual income
    -- double check if i can switch networks given the same number

    mobile_no,
    IFNULL(h.network_group,g.network_group) network_group,
    CASE
        WHEN g.network_group = 'Globe' AND h.network IS NULL THEN 'Prepaid'
        WHEN g.network_group = 'Globe' AND h.network IS NOT NULL THEN 'Postpaid'
        WHEN g.network_group = 'Smart' AND (LEFT(mobile_no,5) = '63920' OR LEFT(mobile_no,5) = '63918') THEN 'Postpaid'
        WHEN g.network_group NOT IN ('Globe','Smart') THEN NULL
        ELSE 'Prepaid' END network,
    CASE 
    ### social media ###
    -- anything from social
    WHEN LOWER(COALESCE(Media_Source,Partner,Campaign)) LIKE '%social%' THEN 'Social'
    ### direct ###
    -- fwb / referral
    WHEN COALESCE(Media_Source,Partner,Campaign) = 'af_app_invites' THEN 'FWB'
    WHEN (Media_Source = 'invalid_media_source_name' OR Media_Source IS NULL) AND LOWER(Campaign) LIKE '%refer%' THEN 'FWB'
    WHEN LOWER(COALESCE(Media_Source,Partner,Campaign)) LIKE '%refer%' THEN 'FWB'
    WHEN LOWER(COALESCE(Media_Source,Partner,Campaign)) LIKE '%moengage%' THEN 'FWB'
    -- apple search
    WHEN LOWER(COALESCE(Media_Source,Partner,Campaign)) LIKE '%apple search ads%' THEN 'AppleSearch'
    -- facebook / meta
    WHEN COALESCE(Media_Source,Partner,Campaign) LIKE '%Facebook Ads%' THEN 'Ads_Meta'
    WHEN COALESCE(Media_Source,Partner,Campaign) LIKE '%meta%' THEN 'Ads_Meta'
    WHEN COALESCE(Media_Source,Partner,Campaign) = 'facebook' THEN 'Ads_Meta'
    WHEN LOWER(COALESCE(Media_Source,Partner,Campaign)) = 'restricted' THEN 'Ads_Meta'
    -- google
    WHEN COALESCE(Media_Source,Partner,Campaign) LIKE '%google%' THEN 'Ads_Google'
        -- tiktok
    WHEN COALESCE(Media_Source,Partner,Campaign) like '%bytedanceglobal%' THEN 'TikTok_Paid'
    ### affiliates ###
    -- pokkt source
    WHEN LOWER(COALESCE(Media_Source,Partner,Campaign)) LIKE '%pokkt%' THEN 'Aff_Pokkt'
    WHEN COALESCE(Media_Source,Partner,Campaign) LIKE '%Tonik_CPA%' THEN 'Aff_Pokkt'
    WHEN COALESCE(Media_Source,Partner,Campaign) LIKE '%campaign_name%' THEN 'Aff_Pokkt'
    -- tyr ads
    WHEN LOWER(COALESCE(Media_Source,Partner,Campaign)) IN ('tyrads_int','tjzymob_int','tyrads','ta_tonik_aos_ph') THEN 'Aff_TyrAds'
    -- sales doubler
    WHEN LOWER(COALESCE(Media_Source,Partner,Campaign)) LIKE '%salesdoubler%' THEN 'Aff_SalesDoubler'
    
    -- imoney
    WHEN COALESCE(Media_Source,Partner,Campaign) LIKE '%imoney%' THEN 'Aff_iMoney'
    -- moneymax
    WHEN COALESCE(Media_Source,Partner,Campaign) LIKE '%moneymax%' THEN 'Aff_MoneyMax'
    -- jeff
    WHEN COALESCE(Media_Source,Partner,Campaign) LIKE '%jeff%' THEN 'Aff_Jeff'
    -- shareit
    WHEN COALESCE(Media_Source,Partner,Campaign) LIKE '%shareit%' THEN 'Aff_ShareIt'
    
    -- appnext
    WHEN COALESCE(Media_Source,Partner,Campaign) LIKE '%appnext%' THEN 'Aff_AppNext'
    -- mediadonuts / entravision
    WHEN LOWER(COALESCE(Media_Source,Partner,Campaign)) LIKE '%mediadonuts%' THEN 'Aff_Mediadonuts'
    WHEN LOWER(COALESCE(Media_Source,Partner,Campaign)) LIKE '%entravision%' THEN 'Aff_Mediadonuts'
    -- shopback
    WHEN LOWER(COALESCE(Media_Source,Partner,Campaign)) LIKE '%shopback_int%' THEN 'Aff_Shopback'
    -- deepsea
    WHEN LOWER(COALESCE(Media_Source,Partner,Campaign)) LIKE '%deepsea%' THEN 'Aff_DeepSea'
    -- avow
    WHEN COALESCE(Media_Source,Partner,Campaign) LIKE '%avow%' THEN 'Aff_AvowTech'
    -- avow
    WHEN COALESCE(Media_Source,Partner,Campaign) LIKE '%vivo%' THEN 'Aff_Vivo'
    -- 711
    WHEN COALESCE(Media_Source,Partner,Campaign) LIKE '%SevenEleven%' THEN 'SevenEleven'
    ## organic ##
    WHEN COALESCE(Media_Source,Partner,Campaign) IN ('af_banner') THEN 'af_Banner'
    WHEN COALESCE(Media_Source,Partner,Campaign) LIKE '%sendgrid%' THEN 'Organic'
    WHEN COALESCE(Media_Source,Partner,Campaign) IN ('Website') THEN 'Website'
    
    ## owned media ##
    WHEN media_source IN ('PRFlexLoans_WebAndroidPressRelease') THEN 'Owned Media'
    
    WHEN media_source IN ('invalid_media_source_name') THEN 'Invalid Media Source'
    WHEN media_source IN ('None') THEN 'Broken OneLink'
    WHEN media_source IS NULL AND partner IS NULL AND campaign IS NULL THEN 'Organic'
    ELSE COALESCE(media_source,partner,campaign) END as Source,
    media_source,
    partner,
    campaign,
    
    FROM ac_created a
    LEFT JOIN f_loan b ON a.cust_id  = CAST(b.customerId AS STRING)
    LEFT JOIN deposit_balance c ON a.cust_id = c.ofcustomerid
    JOIN af_link d ON cast(a.cust_id as string) = d.customer_user_id
    JOIN prj-prod-dataplatform.dl_customers_db_derived.Tdbk_customer_mtb_age_derived e ON a.cust_id = e.cust_id
    LEFT JOIN demog_details f ON a.cust_id = f.cust_id
    LEFT JOIN `prj-prod-dataplatform.manual_source_extracts.mobile_carrier_mapping` g
    ON LEFT(RIGHT(mobile_no,LENGTH(mobile_no)-2),3) = CAST(g.number_prefix AS STRING)
    LEFT JOIN `prj-prod-dataplatform.manual_source_extracts.mobile_carrier_mapping` h 
    ON LEFT(RIGHT(mobile_no,LENGTH(mobile_no)-2),4) = CAST(h.number_prefix AS STRING)
    WHERE 1=1
    ## The deposit account of a customer upon the 90th day is greater than 100 
    AND clearedbalance >= 100

    ## The customer did not initiate any loan process within 90 days from account creation
    AND (DATE_DIFF(DATE(startApplyDateTime),DATE(created_dt),DAY)>=90 OR b.customerid IS NULL)
    AND c.ofcustomerid IS NOT NULL
    AND cast( a.cust_id as numeric) in {a}
    """

    demogdf2 = client.query(sq).to_dataframe(progress_bar_type = 'tqdm')
    
    demogdf2 = demogdf2[['cust_id', 'network_group', 'Source',	'media_source',	'partner','campaign']].copy()
    
    demogdf2 = demogdf2.drop_duplicates(subset='cust_id', keep='first')
    demogdf2['cust_id'] = demogdf2['cust_id'].astype(np.int64)
    # Dictionary mapping Source values to their SourceGroups
    # print("Dictionary mapping Source values to their SourceGroups")
    source_groups_mapping = {
        'Ads_Google': 'Direct',
        'Ads_Meta': 'Direct',
        'Aff_AppNext': 'Affiliates',
        'Aff_AvowTech': 'Affiliates',
        'Aff_DeepSea': 'Affiliates',
        'Aff_Jeff': 'Affiliates',
        'Aff_Mediadonuts': 'Affiliates',
        'Aff_MoneyMax': 'Affiliates',
        'Aff_Pokkt': 'Affiliates',
        'Aff_SalesDoubler': 'Affiliates',
        'Aff_ShareIt': 'Affiliates',
        'Aff_Shopback': 'Affiliates',
        'Aff_TyrAds': 'Affiliates',
        'Aff_Vivo': 'Affiliates',
        'Aff_iMoney': 'Affiliates',
        'acesaatchi': 'Affiliates',
        'AppleSearch': 'Direct',
        'Broken OneLink': 'Others',
        'Email': 'Others',
        'FWB': 'Direct',
        'OpsEngine_post': 'Others',
        'Organic': 'Organic',
        'Owned Media': 'Others',
        'Partnership': 'Others',
        'SevenEleven': 'Others',
        'Social': 'Organic',
        'Test': 'Others',
        'TikTok_Paid': 'Direct',
        'Website': 'Organic',
        'af_Banner': 'Organic',
        'Tonik_PHL_default': 'Others'
    }

    # Assuming demogdf2 is your DataFrame
    # Create the SourceGroups column by mapping the Source column to the corresponding groups
    demogdf2['SourceGroups'] = demogdf2['Source'].map(source_groups_mapping)

    
    dfmain = dfmain.merge(demogdf2, on = 'cust_id', how='left')
    
    # MOB
    # print(" MOB")
    
    # Step 1: Convert columns to datetime datatype
    dfmain['onboardingDate'] = pd.to_datetime(dfmain['onboardingDate'])
    dfmain['startApplyDateTime'] = pd.to_datetime(dfmain['startApplyDateTime'])

    # Step 2: Find the earliest date between onboardingDate and startApplyDateTime
    dfmain['earliest_date'] = dfmain[['onboardingDate', 'startApplyDateTime']].min(axis=1)

    # Step 3: Calculate the difference in months from the earliest date to current date
    current_date = pd.Timestamp.now()
    dfmain['months_difference'] = (current_date - dfmain['earliest_date']).dt.days / 30.44  # Average days in a month

    # Round the result to 2 decimal places
    dfmain['months_difference'] = dfmain['months_difference'].round(2)
    # dfmain['DataSet'] = 'Demographic Data'
    
    return dfmain

# %% [markdown]
# # Main Query to run the loop between start date and end date

# %%
start_date = datetime.date(2023, 1, 1)
# end_date = datetime.date(2023, 3, 1)
end_date = datetime.date.today() - datetime.timedelta(days=1)  # Yesterday
res =  pd.DataFrame()
for date in get_date_range(start_date, end_date):
    print(f"Processing date: {date}")
    df = CustomerIdentify(date)
    print(f"The shape of the dataframe for date {date} is:\t{df.shape}")
    b = tuple(df['cust_id'])
    df['cust_id'] = df['cust_id'].astype(np.int64)
    a = tuple(df['cust_id'])
    # print(a[0:5])
    # print(b[0:5])
    dfd = demographicdata(a,b, df)
    # print(dfd.columns)
    res = pd.concat([res,dfd])
    # Assuming your dataframe is named 'res' and the column is 'onboardingDate'
    res['onboardedDate'] = res['onboardingDate'].dt.date
# Out:
# Processing date: 2023-01-01
# The shape of the dataframe for date 2023-01-01 is:	(778, 2)
# Job ID 546a889a-304d-4b73-9955-38f2fa10ac68 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID a42df99b-7131-4c6a-a922-5af65da77bfc successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID fcaad739-9b4d-4996-b2e4-16a72bc3b83f successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID eaf550ce-f9c3-4f13-8c17-dcb05ec8bf4d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID fc04c04e-c330-4b87-a95c-e76aa42c8a03 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID be6cc3c7-4136-4072-b647-f1d60e80a5dc successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 5030565f-a10d-4624-af0a-8b61bf34d357 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-02
# The shape of the dataframe for date 2023-01-02 is:	(1417, 2)
# Job ID b87ea5dc-98a6-44da-aa7a-4f75cc98203b successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID bc5cf45f-2f88-44c1-8202-61221fa49b6c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID ef696c1f-9ecf-4a4f-a465-d2b9ff81ab84 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID f9215b84-9481-4118-8042-bea35f893c5b successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 769cba32-afee-4a16-9ef9-4920c83f55bd successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 8b931a74-f1e9-450f-a5db-6e8dd7153c43 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID eab8ef8c-73e8-48cf-92fc-afcef9ee1856 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-03
# The shape of the dataframe for date 2023-01-03 is:	(1274, 2)
# Job ID 14ed88ae-6ca6-4396-a792-582908e7cef7 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 54ae222c-8968-45a3-8ddb-acf5f6072be8 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID e340b86a-6de2-4805-86c3-dbe7472c7dfd successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 7afb427e-a908-407f-afb3-7dba52b05420 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 2e77bb83-83d6-48f6-86bd-7727315420cf successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 3800fb02-c341-4389-8893-24c17da4ec8a successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID d8ab6651-b5bf-488d-a333-fb177fe54a49 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-04
# The shape of the dataframe for date 2023-01-04 is:	(1377, 2)
# Job ID 8f41acaa-f933-4e54-8ca8-84a3b4b631fa successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID e54f6066-52b6-4d49-b2bd-7c92d6960a96 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 6ada9972-23dc-48c1-b42b-bdc1ce16a665 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 1f64c467-c6c9-4a72-9cc9-c9c27bdc4fab successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 56ebcc61-1823-45f1-8158-b700db77ffc9 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 406b990c-3e7a-4959-a875-bf1a85d2b468 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 959ea4a5-e727-42e4-9ea1-2210d357fa5b successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-05
# The shape of the dataframe for date 2023-01-05 is:	(1228, 2)
# Job ID 1161c1c3-f654-4518-8845-0c69ba57b4bc successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 9dce855c-9d35-444e-bcb9-b89eae6b3fd0 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 2b562b69-0258-4820-b246-0647ff992773 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 603a4cb3-d857-4c9d-bca2-c8140a69e9ea successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 5d9bde67-d278-4bb0-9c13-be874a59d270 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID e9edc396-85b8-43b9-b67a-b7bf461533c8 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 0c4de9c1-7912-4403-8df2-71a5149c746f successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-06
# The shape of the dataframe for date 2023-01-06 is:	(1209, 2)
# Job ID 7311dc5b-ae75-4068-9397-1d4d0be4aedd successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 9d3cae91-5f2a-4cf9-9b2b-bb110dc5545e successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID d8672c5e-beb7-4224-b129-ac344cf6fd64 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 0ea254b8-7299-45d4-b3db-2dac88b92e05 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID c5470eea-ff07-4f5a-8d95-0038e6f8011e successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 1d5fc8ee-0186-4886-9462-68f359ac4312 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 1f790978-6e9f-44ba-b62b-fb984177e529 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-07
# The shape of the dataframe for date 2023-01-07 is:	(1146, 2)
# Job ID 97b384fd-ff83-4269-9891-060d648b0e17 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 6bc11267-fe04-45c3-b293-7d9075f2ab1a successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 420dd8ae-a1d4-4100-a742-d2ba0270ea91 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 4f97a2d6-5572-4ba0-b6f3-ec284bb9eefb successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 23494064-dcac-418e-9127-4a3c8dc08d98 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 0b3dd0fb-e126-4f32-86ef-4b15b06fbfb5 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 83b092c5-af58-4670-a9e1-65d4ef65a1ff successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-08
# The shape of the dataframe for date 2023-01-08 is:	(1162, 2)
# Job ID 5294b06d-9305-4d74-9f91-b87615b4b8e8 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID bad4b31b-1cab-4d84-b64f-587abaa62a50 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 2a709783-6e9d-4cd2-a0b9-b08cdb43f08c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID b187c69c-d842-4510-a76d-17cd76059634 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 706268c0-97ba-4997-8c34-4a0ad1720632 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 701bd4fa-490d-4a66-a841-aaafb41b0ac9 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 82936806-fa50-4846-87d9-99d72709c52c successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-09
# The shape of the dataframe for date 2023-01-09 is:	(1121, 2)
# Job ID 783ca0d3-3119-4db8-965c-773164a80387 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID defb72e3-b83d-4b3d-b158-8a55339e714f successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 81ebcef0-feb0-41d3-b62f-aab175b47d5d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID fce4f3d0-9583-48f8-880b-d3423740344c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID d1f3d273-019a-4b17-a1dc-0ec43ee111fa successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 434bdec9-b468-4d46-8939-a31a1c3c8e4c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 4181815a-abb7-4980-ae14-029341019e9d successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-10
# The shape of the dataframe for date 2023-01-10 is:	(1196, 2)
# Job ID 057e0192-55d4-499f-842b-0318ee9e79b9 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID c7048aec-fafb-479b-a4b2-ab637875beaf successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 0670d4e4-44d7-4cee-8ba0-177dcf24b2e8 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID f6f1fbb1-b592-4847-b9af-0645e257433a successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 9b5a7e23-4fd0-44fd-ab56-dbd5d5a44f30 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 047ab024-2304-424e-8a87-a16e38263860 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 75ce85b7-0b9d-4148-9f51-83cfb32c6e26 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-11
# The shape of the dataframe for date 2023-01-11 is:	(1020, 2)
# Job ID a7d291d8-e495-47f2-b79f-18936a476225 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID b28a217b-7da0-47ea-b8e7-69aae1982f3c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 8faced45-64b8-4da2-8f9f-260411969235 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID f76e2053-4273-48bd-9f46-6602d35bc8dc successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID ff6d6d77-e32f-4d1a-b450-eeed772b3e48 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 60c3bc5a-029a-4559-a31c-b9a0999b838f successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID de0a1a68-7a2e-45b3-afcc-a5ab927af5a4 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-12
# The shape of the dataframe for date 2023-01-12 is:	(1030, 2)
# Job ID 43ab722f-9075-4382-957d-780b01a20fb0 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID a0bfb26d-be06-4da2-87f6-575525acc077 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 6a9f3178-c1de-44be-9ed4-803c86dd307a successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID aceec3e9-fe1f-44d9-98f2-170490fbd39c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 0a655046-83e0-45c7-abad-adeb646b9114 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 950364c0-76d5-44d3-ba05-49692c14ab39 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 374f7c96-0da6-41f8-9fd3-f18f069ecc24 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-13
# The shape of the dataframe for date 2023-01-13 is:	(1137, 2)
# Job ID 2b6c16f1-2f5f-4933-80c0-0acae642fa87 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 1f795fb8-e451-4a81-b803-3c738302ffa6 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 634dd6e8-8c14-47b9-ad9a-c29ee4ab0cdf successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 50d08666-1363-4cd8-9947-a65f03cd8553 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID deeab52c-a7ae-49fe-93d4-07e16ffe9df6 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID a32d4431-6228-4a93-bf80-09a05621bbb7 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID aa64c526-7958-41da-8e25-85d3b61bfef6 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-14
# The shape of the dataframe for date 2023-01-14 is:	(1123, 2)
# Job ID 02c715b3-82ef-44da-bab6-06f72a2c4424 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 89d139f8-c03f-4ef2-acbd-7dc14e7fcf8a successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 7df789ce-215f-44a4-8e13-3736643c08c5 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID c63ff459-42d1-44aa-9a66-d60c2eb43dfe successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 81ce210f-a803-46d2-be58-233903ce8b99 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID aaa8b1a6-5810-448d-aa83-0e42165cd4f4 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 4c359743-7bd0-4e7f-9022-8361b178ebf4 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-15
# The shape of the dataframe for date 2023-01-15 is:	(1012, 2)
# Job ID aa5063c5-a270-4d1f-85c4-546863f80d0f successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID db673783-7c0c-48da-abe8-76eb9a13f840 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID bd477ad3-9d45-4a0b-b1d8-072d04346eb5 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 5c3331de-ede9-4083-bea9-36c276a91399 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID a92264ad-9a2a-45bb-929c-9f4d4ab4d698 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 0acf1d81-da24-430f-a3c2-f6ebe834765c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID af3e0b69-ccc7-4913-8c7d-bae69dd0a68b successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-16
# The shape of the dataframe for date 2023-01-16 is:	(1110, 2)
# Job ID 8616ee30-5c19-4ea2-b379-a55eb073b953 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 7ddc5aa1-2761-4429-a1ac-7630887b04a5 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 11c4adcd-0f80-46f0-8cc0-b6f10d115629 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 3cb4f370-8391-4173-a23d-abb56cf4dca7 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID a1757390-22fd-4185-a73b-e71feebfbd11 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 37648c52-3432-42fe-abc6-b408770646be successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 349f36be-11ba-410b-ad3a-0a8d311a3863 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-17
# The shape of the dataframe for date 2023-01-17 is:	(1168, 2)
# Job ID 471ffe1c-e806-47ae-924e-7671d352ae59 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 4c7f9cf1-2613-40ff-8080-638b772bd42d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID b0ff3e93-cf7d-4fd5-a721-43ceb8b50f3b successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 5ddd2b2d-a872-4e69-98f4-077a945962fa successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 90d3b10d-7b3f-4ef5-94c3-4bd886f95d09 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID c4c43b61-3793-407b-a176-79f17143d7cb successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID bbbcb3c1-2e75-4ca3-abe7-cdda89667eca successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-18
# The shape of the dataframe for date 2023-01-18 is:	(1121, 2)
# Job ID 3c068990-308b-41a8-8a2d-083f1b40bd6c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 443a756b-2fc1-4ccc-bd25-66dfb2e36ea4 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 4df0d74c-603d-47ec-b4ff-f307831ecf97 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID b45933a7-9206-4976-9cda-887ad691e1ae successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 536ad590-0dde-4e04-964f-03cc1a85427f successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID a054fe45-d0d8-4975-a985-5c1da1298c11 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 61b4c1a1-1062-4d46-86dc-5e0e2fb3307a successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-19
# The shape of the dataframe for date 2023-01-19 is:	(1025, 2)
# Job ID 268507cb-d4cf-406c-9b61-bb01a0d44da3 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID ca5a16f8-d3d8-4344-901d-d5f8e85ced8f successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 986944f3-a091-47bb-a5af-a97b0a6943ae successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 1b459579-631b-46c0-b93c-e62d20f20e96 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID add63311-339f-49f9-a20c-1d678324de6c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID d6556c71-bc89-4056-b31e-a5c5c768acf8 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID f173c6df-a3e0-4cf2-b765-a5caa1aa98f8 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-20
# The shape of the dataframe for date 2023-01-20 is:	(1097, 2)
# Job ID fe2613c0-494e-4330-b5f9-b434d6ada514 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID d192825b-5951-47a4-996f-060bb9a64918 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID f754d2db-861f-46a9-97ca-3d82b3370d8d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 642c6cf5-8577-44db-be8a-e4f5e2bd713c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 64920abd-a24b-4bf9-a71d-e3a46756535a successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 3cafaea8-d29f-4258-ae0a-6ad1c83b4077 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 5d7e2567-3365-4f99-a455-f8220caf89be successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-21
# The shape of the dataframe for date 2023-01-21 is:	(1025, 2)
# Job ID 7d300c87-c2ca-4f0a-b9e0-bde914505ac5 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 8c2341ce-9550-4396-b848-0bf62837cd1a successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 73cb1cfe-87ee-41c9-a5af-a7df40ad8422 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID efc704ab-9454-43fc-a9d7-7a19e7c44549 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID d4e248ef-575b-430e-9f26-059e9bb68c9e successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID c9f84482-d7fb-4fe7-af80-38569de2e1cd successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID fd205ebf-bfac-47fc-b15e-9e16417956f9 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-22
# The shape of the dataframe for date 2023-01-22 is:	(1086, 2)
# Job ID 994b952b-a57d-4022-b2f5-30773feceb0f successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID ee164386-d4db-415e-ba5b-7f365a62724a successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID d85c1590-e3d7-46a2-ab48-c20896a3cd2e successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID c6dc45e0-5dce-44ca-a6bb-ceae665170d9 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 400cd97f-a257-45ef-91b1-a0d2ba4d90a1 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 946fcff0-7669-4747-859a-f6ddf9b0fffc successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 93705bc4-8ae8-4851-acce-36c0e43958a7 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-23
# The shape of the dataframe for date 2023-01-23 is:	(1119, 2)
# Job ID 003745b0-086b-48f4-a121-b8192523e954 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 3cc55afa-c832-4d4a-a316-de6042a601f1 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 467fdee0-e10c-413b-b673-ff4193882cbf successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID a680736d-2f5a-4559-a948-38f6dfbbb0ab successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 917a1260-5575-4b1c-a4e1-e64eee5aee2c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 3aa5ba16-bba9-44dd-99a9-7668fec3c661 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID cd811c33-2b47-46b4-9156-d8a6110931a2 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-24
# The shape of the dataframe for date 2023-01-24 is:	(1162, 2)
# Job ID 397c724d-10d8-47b7-9667-b84239aebfc8 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 10be270b-b5f4-41c0-90d1-e00df91e1f52 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID e8e7df44-f64f-4a94-9b73-3737a85a1c63 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 137d7d07-8a81-47d0-86a5-245e53739dd0 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 483e306d-17a4-4d4a-87f9-fe0e73f49bba successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 16442845-90a3-4db1-b0c0-02cb5776a1ae successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 449f4c13-97d6-4af3-8b90-e69eeb6c7d9c successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-25
# The shape of the dataframe for date 2023-01-25 is:	(1182, 2)
# Job ID 44f756af-ff9b-4e3b-bcf9-a83cd9195fe7 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID b06afe42-76ac-4bff-95d7-e3d25614efb6 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 83b727d6-6235-4fc8-81f0-eac7d21c3097 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID e4b44e8a-60b7-4b82-95b8-cd9350c811a3 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID e385465d-f095-432c-bf66-b83225d087fa successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 7bf2a9ad-1c8c-4ca0-a6d0-edc07728160f successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 6f8002bc-6bd4-419d-955c-ab4d0fec843e successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-26
# The shape of the dataframe for date 2023-01-26 is:	(1171, 2)
# Job ID 09b657de-d563-442e-8b77-f5e29bca069b successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 0b387ad8-7a81-4bbb-9225-43e4c24580ca successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID bcec87d0-2744-4ba4-ac12-6c35e598b401 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID b71a1e45-c8f8-4349-a914-01747ed342d1 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID c96b27a3-7c3f-48d1-a715-df75b1752790 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 13502e7a-9419-45c2-bdd9-932ea2b73593 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 02f6b91a-67aa-42fb-ace4-0f7a5d162d28 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-27
# The shape of the dataframe for date 2023-01-27 is:	(1129, 2)
# Job ID 948d3b90-bd1f-48f6-91d7-db15d769a743 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 4f60a622-97a1-4bf8-90f0-e9609045a120 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 74bc930e-c78a-44ef-b7c6-3fed058e1b36 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 16e86b60-855f-4d4a-b44f-7d3c71f40838 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 421cfeb4-d7d2-4f9c-86eb-261d8eceddd5 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 40c01e8b-d481-4231-8d9e-1db275ccfe44 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID e848e96e-1345-4312-87cb-fc432b23b6d6 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-28
# The shape of the dataframe for date 2023-01-28 is:	(1052, 2)
# Job ID 39d4160d-f334-447e-b4dc-426795a0a14a successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID ff7b9484-6ed6-40a6-8e71-fe090d3111c1 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID eade709e-3b6a-4d5b-b387-57adede8e72c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID b4c0ccb7-5dba-43f4-92dc-0482a513df6d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 904b4cf6-49f5-40dc-8040-32209cf256c6 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 71d0f155-d0c8-47ec-aab0-0492e7e62aeb successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID d753853a-736d-4347-858b-dfd1ad345035 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-29
# The shape of the dataframe for date 2023-01-29 is:	(1244, 2)
# Job ID 162d0404-3cd3-4ee3-92fe-a2653d371391 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 55fc8948-ad15-424b-8947-c793c841d9aa successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 53e44fa2-202a-4a88-9aa9-9310c5b4f267 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 407d1a1e-ecb2-46d2-8790-d4fe4fafd724 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 0d76edf6-4bd8-4360-9648-f550c44792e7 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 38a42417-3a95-4219-8a70-2ccba5d55cc0 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 09644df0-df76-4ef8-baa5-deadf402043c successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-30
# The shape of the dataframe for date 2023-01-30 is:	(1341, 2)
# Job ID 184cedd9-9cae-4c28-b513-d81d919894ab successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID a3f99cd6-a91e-499a-b29a-3bf1385a4af3 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 6e333134-7e44-4faa-8c30-a6cd58c453d2 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID e17c4f44-5c08-4282-b6c0-d1519eb6afea successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID be3fdcff-807b-411d-98a9-75aa72aac207 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 8ad16ba2-a198-4ae2-badd-3443bb784b74 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 74d0ec86-8673-48da-9766-8df17f6fbbe2 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-01-31
# The shape of the dataframe for date 2023-01-31 is:	(1413, 2)
# Job ID 60269943-2877-42be-a2e2-9ebad2c83be4 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 94f4dc37-9c71-4814-a863-77da013f6a7e successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 8f919ab8-f97d-468b-935e-f84371cf7283 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 924f68d5-abb3-425a-b1e0-94c8ac7510ef successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 465f7967-2a9e-4fc1-ad40-75273d859451 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 452fd80e-0318-425d-b7bf-354fbcb7019a successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 2ef97533-bc71-40da-8b88-7c680a0e1d20 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-01
# The shape of the dataframe for date 2023-02-01 is:	(1331, 2)
# Job ID f87278fc-4cec-4b21-ab69-85d4766bdaf6 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID be84c78b-34d4-49d1-8c0b-1e9e6e3f36a8 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 7f7069b5-56af-4b28-b933-0e013b71b51d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 9a92effa-a5fb-458f-b74f-e86598148238 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 16526c48-b9b8-4e51-b0c9-e4da92fb58d7 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID caf5d5ea-fa32-4d32-8886-5f51d5052bdf successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 8d4a63c9-49f1-471e-b865-7ac204f26ab3 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-02
# The shape of the dataframe for date 2023-02-02 is:	(1335, 2)
# Job ID 05c10994-a820-4b9c-a3d0-d1409a486d2c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 3d0f99b8-fee2-4c4b-ab41-2a4a8bf51052 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 6a1c5aba-1793-462e-96e8-b902b6a9f283 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 4cda231b-95fa-4ba6-be88-c248021bb59f successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 6f67be9b-22b8-4e98-b2c3-3eb560c49241 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 151952f7-c88e-4e13-a7a8-a75ab50aad1d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID e651aae7-4273-4934-b65b-7123e1dc4a5b successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-03
# The shape of the dataframe for date 2023-02-03 is:	(1364, 2)
# Job ID 1e984653-ecd2-4434-ba0b-a21ff304d5c4 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 3f967d5b-2d1b-4711-bc1d-cdf218d1925d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 1f257a8e-3f11-484a-b4fc-c39ac6f80662 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID f18fe50c-9baf-46d9-8291-7e286b699efe successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 9fedf31c-5577-45b7-a49c-619be3b3970c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 0a3263a7-4d9c-4941-9467-0d96610fd8ed successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 92445a00-e789-4507-826f-ed180b6c6c25 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-04
# The shape of the dataframe for date 2023-02-04 is:	(1312, 2)
# Job ID e67cb25c-9a23-47b7-8fc3-a66b58e1303d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID d815b306-7d5d-41d8-9013-c3e060b8fc3b successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 29e4def4-7e8d-42c5-9999-e738e9bd594d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 9ef08d2e-9036-43c0-b8da-c21cd9a60927 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 8d770afe-a049-4c87-83b7-6824624a7483 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 53029d0c-fae4-4bb0-b77a-e06566d780d1 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 8c662d10-c5dc-4979-8ff5-d3c37134fec7 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-05
# The shape of the dataframe for date 2023-02-05 is:	(1386, 2)
# Job ID 44837e48-2fb7-4fed-be92-2ba6e1c64304 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 8242c2f9-f125-4648-9cc2-dc8d720244ee successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 1c3e72f2-fcec-4dd3-99b0-587d1c4eab79 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 6cd98eef-0129-485c-a1b4-9b263c119e15 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID c0e6ab17-27c1-458b-92c2-f5c687d81a8a successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 62281215-113f-437a-bb37-a2331a061fca successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID d8d538d7-deaf-467a-84e2-a411afb49071 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-06
# The shape of the dataframe for date 2023-02-06 is:	(1345, 2)
# Job ID 8f7f1948-f21b-4014-b13a-42e691bdf216 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 96d2ffce-8298-4797-9463-0edbcaeac7ae successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID e5b92383-5f56-44f3-afa2-390c69a55a00 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 1d12c17a-09f7-4431-b329-d59b9e742989 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID bf4cfb2c-096c-4e8a-825e-f290de9110e4 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 657334b5-6a52-42cc-a33d-f85eee43f082 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 9455b4c9-8d71-45ec-a9f1-386a663c4596 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-07
# The shape of the dataframe for date 2023-02-07 is:	(1496, 2)
# Job ID fdf7277a-8550-41af-94ba-4daec78ed58a successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 5e5aabe7-0969-4255-b46b-a04bc2eff9dc successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 4f1487a4-7e36-4d66-b25a-5a19d2c226a2 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 40583618-b24e-46e2-89bf-ab5cfbbfb75a successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 7dce167b-b525-4f98-a511-84a18a62042e successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID cb7542be-018a-470c-9d1e-fe9ca6ec3911 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 031cc735-331c-4080-827a-1126a61719c6 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-08
# The shape of the dataframe for date 2023-02-08 is:	(1513, 2)
# Job ID a43c17ba-a915-4681-bf6f-8558c42042ce successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 482d4994-2f5b-4df1-ac80-87c00fdd9fb6 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 156e16d1-41f6-42aa-bb84-88dbf6e23223 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID b5e21e99-d77b-4a95-99e7-f296f345ca0d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 860d1ca4-8673-47ab-b0bc-a94b0457062e successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 75ce6940-b974-4157-8bd0-cf73c2bfefc5 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 79300571-68c4-4f50-9df4-ca9feb9f8997 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-09
# The shape of the dataframe for date 2023-02-09 is:	(1511, 2)
# Job ID 8f3319d1-5ef7-4b61-9151-b5bd80711e6a successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 3bd52581-2c04-45d1-87d4-df7dd571c37e successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID b582964e-0c30-40eb-ba04-7e7f7c2cefb8 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 4219ce64-4209-4881-9ebe-8993c1dc5233 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 4c8c20f1-ca72-430f-97ee-0c1de337c112 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 1b9d5d6f-87f8-4b48-a922-eb8d97195022 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 91fcea99-1f44-47d2-aa0e-7c167c6ff308 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-10
# The shape of the dataframe for date 2023-02-10 is:	(1384, 2)
# Job ID 80161c76-63e6-44f7-a440-f3145e510070 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 3ce05058-99da-464c-a2e2-3d051f686589 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 0105386b-ca40-4c62-9bce-77bf8e1f5843 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 9b07cbf7-5223-472e-886a-47eeb5d1a566 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 17cf77e5-9810-485a-b510-69107f8d6e57 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID b7dbbf9b-9957-4540-bffe-a20434866e0b successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 24d0848f-6461-4475-8933-15df401a22e9 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-11
# The shape of the dataframe for date 2023-02-11 is:	(1443, 2)
# Job ID 2702bfdd-3b4d-4f4d-9ba9-5961f7c77264 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 5082a83e-3339-4531-a864-5fea77f5d6a9 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 238796ed-e614-4d6d-9000-f6c276afca42 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 322e8f62-899b-44b4-9f97-5b71ccb99a77 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 344edba8-a429-4dbc-8bb7-a5ca50a99e7c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID a1c416e5-32a4-4d2c-a8df-837221eb7410 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 5d1acb1b-8c35-4ba1-9f5a-2fb7c2a81754 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-12
# The shape of the dataframe for date 2023-02-12 is:	(1349, 2)
# Job ID 9dba1d0b-8679-45e6-89bb-1d927e295cdb successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 28a496f4-fbd2-40b8-87f6-5a1a9a7f006c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 3c2edcf7-32b7-4c8a-b71e-05c461bb027b successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 0fdaf15d-892b-4c78-8fd4-85d3e22b7d4b successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 2c58b01b-2fee-4117-a9fa-e6a4f2f86a2c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 065461cd-eb5e-4dfd-8adc-9a97c06e726a successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 6cbe5071-9d4a-4869-9fa1-e89aa4b9af0c successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-13
# The shape of the dataframe for date 2023-02-13 is:	(1441, 2)
# Job ID 72b7301f-072f-4aa4-8514-0e7d82e19969 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 5c29ba59-9368-4061-ace6-c87d4d0ec61f successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 71abfd23-0b37-40f0-8532-a3289136de9e successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID d3a6be7a-bc91-4856-8016-4fe8555620aa successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 491a855c-192c-40a5-9e0c-997ba83be425 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 3888a0b5-1ba9-46d7-85a9-745de8fe873f successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 3c12aba4-07cb-4423-bcd3-fa4f93fdf1a7 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-14
# The shape of the dataframe for date 2023-02-14 is:	(1331, 2)
# Job ID 6bb34578-7901-44b2-9993-712ec0025bf7 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID b3f4b04c-0bc9-4b3d-8aa6-6b45fe51d701 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 097ffa87-e9b1-47f7-8cc9-76fbb4f940cf successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 7318a63c-bd1a-46e7-9eb0-b578937a855f successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 550deacb-55c7-4178-98c5-f339fa10493f successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 0052689b-dddb-4d4a-a9e4-6982eb2bc6c9 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID c43d5b44-9030-4fcb-bc5e-7a0e592cb0ad successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-15
# The shape of the dataframe for date 2023-02-15 is:	(1514, 2)
# Job ID 869fc7a1-910d-4220-9faf-c010d4edf7fd successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 8cc17af2-8265-4b9d-8eab-9be783b8efc3 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID dad54b82-cf9e-4796-b8bb-2a037d1f1e79 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 3232cc7f-8824-4446-be9c-4ff2b788fa0d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID e5ae3500-ebae-466c-9727-ce221fce5484 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 621825c8-9d64-4268-ade9-ca3f76a1b4f1 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID da35f661-56df-4886-9a95-5cf6e7d37568 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-16
# The shape of the dataframe for date 2023-02-16 is:	(1572, 2)
# Job ID 45ad4f9c-e62f-4ed8-9e1c-452a8f023489 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 783df9f3-df6b-467b-9cd5-6d604d6f95cf successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID f6cf3e40-746b-417a-8651-d13a95173652 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 3f40646a-e977-4b26-9a12-2545b300f7d0 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 5e7e0587-9ffc-4248-8550-7edc45beac89 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 639baf49-44f4-4d19-8954-f67c39073c31 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 2ef585c1-037a-4135-b975-0ce6f48c31e0 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-17
# The shape of the dataframe for date 2023-02-17 is:	(1453, 2)
# Job ID b7954c1e-ffa8-4208-b870-8e87853b8b8d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 651e3737-cb26-4465-83ad-b68cd00ae100 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 3a5ba30c-b0ca-4d1c-8b07-b06f4731fb7d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 0eb47b4e-6cdf-45f8-8ada-a3b77584c6a0 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 2672dca9-a3bf-4389-8c46-7d523f3e9289 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 407bd720-737c-4462-a6e3-c21da4a9e557 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID fc950413-237f-4348-abd6-6b27343f73eb successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-18
# The shape of the dataframe for date 2023-02-18 is:	(1385, 2)
# Job ID 3bdb2e55-464a-49e8-973a-a0a57aefca36 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID b8f9cbd2-83b6-4024-aefe-90933edc5f11 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID ff4090df-9d58-44e8-bad6-a18873a31270 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 2a7e7f0a-8a6d-487c-a5fb-8a3b105c0361 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 5e3dc0a3-460d-4860-9ca5-57b7aae0438c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 8e9f8a01-a5f7-4545-9f05-57f54b28da4a successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 91d434f1-e207-4bcf-a67c-1fbfcc8211ad successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-19
# The shape of the dataframe for date 2023-02-19 is:	(1412, 2)
# Job ID 936fae37-b458-4212-8343-031bd8c8f9c6 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID c0028569-0d4b-487b-808c-878c73906af4 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 177ada1d-77ba-46bd-a4eb-457fbab8306d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID dea8a02e-2002-4df5-8605-da14ed9fef5d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID eab1cde5-4393-446a-831e-a19c2bb4a1b3 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID b0a22f7a-8510-4795-a7ac-1f190ec1a60c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID dc3be718-e84f-4706-9e1b-3d9572727109 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-20
# The shape of the dataframe for date 2023-02-20 is:	(1543, 2)
# Job ID 694e99d8-40ed-4751-81ed-e795e1be4b32 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID fde7976e-6512-4bd5-a5c6-0f9f0403bb91 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 15788901-8500-4c91-aa7e-f867537a5360 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 7241696f-8f4c-46b6-8c0d-0f8f9771d1a0 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID fb0bf11b-642e-40de-9b75-894b2dafc135 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID a86fa76c-7b93-4660-baa4-677eb34f8ca1 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID ed7c06ae-3254-4e4b-b5bb-ff9320de5c90 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-21
# The shape of the dataframe for date 2023-02-21 is:	(1595, 2)
# Job ID 4ba4fde6-9499-4ed4-884a-fcdd2075dccc successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 103bb92b-ee6b-4315-ac49-d0fbf21d0add successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID ed0adf0c-cfae-4606-b848-c0458b5347c6 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 1ba467d8-fbf7-4cb0-b54f-2edc7c11b3ac successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 21789ae1-023f-4e06-be79-05425fc5cda5 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 7bc28cae-002b-4f6a-8970-cc7dbb4f5855 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID fb8a24d8-e6c8-4e8e-8867-fa668194d409 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2023-02-22
# The shape of the dataframe for date 2023-02-22 is:	(1617, 2)
# ...
# Job ID fbf009b7-e72d-4af2-b054-e1b6371e9614 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 614e6988-4df6-4cf7-815f-a43fe2e4b7aa successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 54f98e29-26d1-4c7d-8c82-0abdfe390bb6 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2024-08-22
# The shape of the dataframe for date 2024-08-22 is:	(3210, 2)
# Job ID 65fccc93-3861-4ae0-bb0c-d61ebfe513ba successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 36bbe9c0-a32f-4336-a0f0-8d29089bd09b successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 389ff051-4f23-42ac-a23c-4e1812ed8760 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID acca9b96-da00-4fd0-bd03-23357d940511 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 9f2cf4c0-a2d2-4844-9460-d2194532fe2e successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID fbeaf436-1e66-4de7-b0cc-23818d7035ca successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID ffe5fd4a-5feb-4a6c-8ff5-6791203be15a successfully executed: |          |
# Downloading: |          |
# Processing date: 2024-08-23
# The shape of the dataframe for date 2024-08-23 is:	(3512, 2)
# Job ID d3085ae0-8a9f-4d23-b09b-2998aea9ce87 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 2d1e2c2f-9808-46c4-a8dd-f706e5d71542 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 2592f7ba-8a09-46dd-8b1d-04483dcb6d29 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 7292859f-498d-4139-8cec-2e0880adcd94 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 3d2f2f95-9140-4644-a008-8509249db8fe successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 988a471c-9ce7-464c-b2e3-fd5eca80e124 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 1f2100e3-3905-4359-8867-825801e1a7fd successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2024-08-24
# The shape of the dataframe for date 2024-08-24 is:	(3329, 2)
# Job ID ef5c6f47-0306-456d-bd47-daf9f9ae0a1b successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 882b890e-7b99-43b5-a1d4-1a79b4555916 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 07e3738a-f029-4f16-9c74-ab852be8672c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 662c4e84-f5f7-45e6-a044-08f7b2f532e2 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 850f5b3b-fc25-4caf-9169-8bb40def19e7 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 704361a2-3def-440f-99b0-444d149f36ff successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID b2f681c4-fefc-49bb-98ff-d001b6790572 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2024-08-25
# The shape of the dataframe for date 2024-08-25 is:	(3601, 2)
# Job ID f6ffa2c0-3b0c-4283-b2f0-7e673e7e4bbb successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 7b292494-ad30-4fc4-9632-0a787160cfbd successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 71fa8d64-cf20-413c-9037-30fe446f7be4 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID f02b577f-c521-416c-a6f1-efa5a14ad7dd successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 34479167-5aa3-41b4-9cb7-d63033b5f976 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 1cb8faa7-de3e-4e3c-a1a5-6ea23f5c5080 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 46aab725-60ba-4c4e-ada1-f06433914823 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2024-08-26
# The shape of the dataframe for date 2024-08-26 is:	(3476, 2)
# Job ID d6857e4e-35ac-444f-9ea0-54f756a752ba successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID bbf339f5-d3a6-4c10-b519-b9fc5edde268 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 506f1391-2e25-4c85-b454-1b71f4aa4cd8 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID a29fe298-6141-4ba5-8ccf-2d7a9889a664 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID b3343ebf-bdf5-4431-b692-b070eb6c9ad7 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 448f3615-d998-4479-afbd-a7ad66ac8d67 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 190473c9-18dc-4bf2-83e2-c6d20b88f531 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2024-08-27
# The shape of the dataframe for date 2024-08-27 is:	(3278, 2)
# Job ID 065e7f4e-b217-472c-b639-d3d221d82610 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 24e69237-795a-4a5f-83db-b12ee3bfba10 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID e256cf3f-ad07-4dc0-8c29-3d9188026770 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 46cdb950-c0d3-40f4-9baa-5d692ce04b3d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID e2a92fda-3d1e-4222-a7a9-a1afeb47423a successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 7e938c0a-72b3-42fd-89ea-779a95a17b07 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID d2578944-5df8-4d9b-a17c-2aca8acf2947 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2024-08-28
# The shape of the dataframe for date 2024-08-28 is:	(3271, 2)
# Job ID 31ee99f0-790e-45d1-8773-0834be035292 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 239f16c5-f3b4-4c95-881a-930975d5a7a9 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID d9c58cb4-972c-403a-8002-0554448e94dd successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID c676a3b7-a656-4ae9-8584-fb249d8987cc successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID a235e738-ca35-4284-b61f-0f92bacd70bf successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 99041dfb-5c8c-49e5-9d0e-b3a74475d106 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 03124596-0e7b-477a-b425-47ca5ff7cde9 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2024-08-29
# The shape of the dataframe for date 2024-08-29 is:	(3109, 2)
# Job ID 3b81d3ea-e8e7-49e4-bcf0-64a3ad81f7e6 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 2626b7e5-110d-4549-a08c-a40113957326 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID d4b0bf92-7a41-445a-b6fb-f23869a3dfe8 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID a13eddcd-e53f-4c32-9d88-12f56a5529ea successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 3c968ee4-e713-42e0-8a5c-f8267ca3647d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID aaf32d8b-37af-48c4-8083-da0dd97b2edb successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID df2f753f-e10b-4236-b3f0-84d7363a952c successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2024-08-30
# The shape of the dataframe for date 2024-08-30 is:	(3157, 2)
# Job ID d14df14f-7211-4f0b-a14d-882f6c3a9601 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 38363987-237c-4104-8820-bb7b54bc26ac successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 143f13ed-5f26-4f36-bd1c-e41acf1072ee successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 44542c25-e639-4ecb-a41a-9a8e7fc06580 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID ac44e535-f526-454e-97d1-eb78dcad5a3d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 320c5d70-e9dc-46b7-887f-7969b4dd4f0d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID dc22da91-65b4-4fb4-9f14-3fc41d313c6d successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2024-08-31
# The shape of the dataframe for date 2024-08-31 is:	(3364, 2)
# Job ID 5ad37eda-51bb-4f08-ad70-505eec00ef00 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 13177d55-e54b-43e0-bdee-77cf117072a2 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 2c4ceb4c-ac9c-4819-934a-358f36720af7 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 3ac47fa7-7bff-4a4b-a41d-21a7263e54ac successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 2c488921-cca0-4c12-8ea0-a3ed18feb6f7 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 31157195-c638-4ec3-a95d-2d4180b22b29 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 73e617a3-4e97-40f2-967f-6e24d7e91e04 successfully executed: |          |
# Downloading: |          |
# Processing date: 2024-09-01
# The shape of the dataframe for date 2024-09-01 is:	(3551, 2)
# Job ID 385101e2-d79d-4e99-bd95-080e594df480 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 69765909-bcff-4ca0-bdca-57a0f3b7f767 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 208b371a-06db-4f0c-90d1-1d8e4418a31f successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID d2544f5d-746e-4289-92aa-192ec0058f12 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 3c2b4de5-e01c-48c8-9a24-7aa801aee92f successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID e8523ccf-cd46-42d4-a848-6b2ec7e6257c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 9663e3be-dc86-4ac7-b57f-29fc362375bd successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2024-09-02
# The shape of the dataframe for date 2024-09-02 is:	(2396, 2)
# Job ID c9c3845a-1a14-4b72-a9bd-b0b2654cde23 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 5b2d9e02-6206-4b09-9cd4-4cd2d5097351 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 372a38bf-ccbb-4bf4-809a-57026152fd9c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID ea81e2d8-cedc-456a-8844-7e1ca210ffc3 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID cf014423-5800-4ab2-b6b6-1db6464eb579 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID d99641af-15ea-4fcf-b9f9-4be7c163b14f successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 498ee424-00ca-4deb-9c27-5275bc93fec9 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2024-09-03
# The shape of the dataframe for date 2024-09-03 is:	(2249, 2)
# Job ID fd863b14-0c7e-47ed-84e6-dd9d0b824727 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 6dc26920-27e6-46e1-87f3-16073b297a01 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID dbfe3f96-1c8b-48f4-a627-723a99b4af6b successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID af39a4be-ad10-41df-847d-3600e31763e7 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 98ca11d0-a9f7-42e2-ac23-c5e42b9038d3 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 5c07dcac-b87d-4519-a0b4-54d78af23331 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID f283aade-6885-428a-b888-78a63d8ee560 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2024-09-04
# The shape of the dataframe for date 2024-09-04 is:	(1909, 2)
# Job ID 9911323f-2a16-4ffa-8cfe-18a680aac9f2 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID e2db3c94-4e33-408e-ad1d-2b04e8ec81ce successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 1ac46474-df7c-4d38-ab94-ca2beb97bf1e successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 561c63bd-da59-413d-9fac-c66e0c7cf671 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 0d6dd3ff-bb62-4ce5-9f4f-5e9a2ccd5199 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID f374490d-14af-4095-a7d1-4ed2864a506a successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 1afaed0d-96ef-4af2-9937-4508ea4cd857 successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2024-09-05
# The shape of the dataframe for date 2024-09-05 is:	(2021, 2)
# Job ID d80f5c02-2ae5-472f-a8fb-f1b9bd4f4546 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 292fc2fc-c7f0-4c08-9181-6b04173cf9f7 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID c2fb1138-b999-4e9b-8437-3bd67becfd48 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 733b1970-f912-44a8-aa86-2c3f0605885d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID aae6d467-08ce-40c1-8f4d-b7d2703083e5 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 804c4727-7ff1-4765-89a9-1bc554bb71c6 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 9ef402dd-fc2f-4a26-9728-fdf9a82ed32b successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2024-09-06
# The shape of the dataframe for date 2024-09-06 is:	(2229, 2)
# Job ID 81171d24-60b2-41d9-b86a-e730bcbf8ec0 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 001e5a0f-61e2-49f7-b712-d48dbf2f3a90 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 1eaba90e-a8ce-45b1-b988-77ad7282a3fb successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 2621b53e-5672-42c1-905d-995db09a81cf successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID dd9fc336-96e1-4f62-b685-67f22c60139c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID deb88e0f-a217-424a-a55e-59f0426081e5 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID e0e796b0-3d8d-4902-b8dd-e8546b287b0c successfully executed: 100%|██████████|
# Downloading: |          |
# Processing date: 2024-09-07
# The shape of the dataframe for date 2024-09-07 is:	(2426, 2)
# Job ID 9ac866a5-b1ce-4793-93af-20391731e81d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 4c644e17-f3a0-41c8-b417-18ec735b49bd successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Merge Client Demo 1 with educationdf
# Job ID 49a1c224-e571-4537-9444-29e0c2e40047 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 2c0a8b0a-fe20-46f9-bd91-64a77934b606 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 72793fdb-7d62-4860-904d-64e1521346a1 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID 89664389-fa76-4dbe-8ab5-2f536df96ff8 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID af733779-8cbc-4f1e-bdbc-e3c41ed93f28 successfully executed: 100%|██████████|
# Downloading: |          |

# %%
print(f"The total rows for {res.shape}")
res.head()

# %%
# # Rename columns and add prefix de_

# columns_to_rename = ['gender', 'birthplace', 'mobile_no', 'product', 'type', 'telcoProvider',
#                      'education_id', 'Education_Type', 'dateOfBirth', 'signUpAccNo', 'kycStatus',
#                      'addressline1', 'city', 'province', 'barangay', 'provinceCode', 'postalcode',
#                      'mailingCity', 'mailingPostalCode', 'mailingProvince', 'natureofwork',
#                      'employmentstatus', 'mobileOs', 'docType', 'onboardingDate',
#                      'Minutestakentoonboard', 'companyName', 'industry', 'device_dtl', 'Age',
#                      'Region_Name', 'Onboarding_latitude', 'Onboarding_longitude',
#                      'loanjourney_latitude', 'loanjouney_longitude', 'ApigeeLogs_latitude',
#                      'ApigeeLogs_longitude', 'maritalStatus', 'dependentsCount', 'monthlyIncome',
#                      'startApplyDateTime', 'network_group', 'Source', 'media_source', 'partner',
#                      'campaign', 'SourceGroups', 'earliest_date', 'months_difference']

# # Create a dictionary for renaming the columns
# rename_dict = {col: f'de_{col}' for col in columns_to_rename}

# # Apply the renaming to the DataFrame
# res = res.rename(columns=rename_dict)

# res.head()

# %%
res['onboardedDate'].value_counts(dropna=False).sort_index()
# Out:
# onboardedDate
# 2023-01-01     486
# 2023-01-02     902
# 2023-01-03     772
# 2023-01-04     806
# 2023-01-05     710
#               ...
# 2024-09-03    1555
# 2024-09-04    1307
# 2024-09-05    1393
# 2024-09-06    1590
# 2024-09-07    1739
# Name: count, Length: 616, dtype: int64

# %% [markdown]
# ## Save the csv file after creating the raw data by running the loop for each day

# %%
res.to_csv(r"C:\Users\DwaipayanChakroborti\OneDrive - Tonik Financial Pte Ltd\MyStuff\Biswa\Customer_360_Data_Prep\Data\Demographic_Daily_Snapshot_Data_20240909.csv", index = False)

# %% [markdown]
# ## Check the column name in dataframe "Res"

# %%
res.columns
# Out:
# Index(['cust_id', 'user_id', 'device_id', 'created_dt', 'gender', 'birthplace',
#        'mobile_no', 'product', 'type', 'telcoProvider', 'education_id',
#        'Education_Type', 'dateOfBirth', 'signUpAccNo', 'kycStatus',
#        'addressline1', 'city', 'province', 'barangay', 'provinceCode',
#        'postalcode', 'mailingCity', 'mailingPostalCode', 'mailingProvince',
#        'natureofwork', 'employmentstatus', 'mobileOs', 'docType',
#        'onboardingDate', 'Minutestakentoonboard', 'companyName', 'industry',
#        'device_dtl', 'Age', 'Region_Name', 'Onboarding_latitude',
#        'Onboarding_longitude', 'loanjourney_latitude', 'loanjouney_longitude',
#        'ApigeeLogs_latitude', 'ApigeeLogs_longitude', 'maritalStatus',
#        'dependentsCount', 'monthlyIncome', 'startApplyDateTime',
#        'network_group', 'Source', 'media_source', 'partner', 'campaign',
#        'SourceGroups', 'earliest_date', 'months_difference', 'onboardedDate'],
#       dtype='object')

# %% [markdown]
# ## Created the rename dictionary from A_Demographic_data_bnb_update excel sheet

# %%
# Read the Excel file (replace 'your_file.xlsx' with the actual file name)
excel_data = pd.read_excel(r'C:\Users\DwaipayanChakroborti\OneDrive - Tonik Financial Pte Ltd\MyStuff\Biswa\Customer_360_Data_Prep\Data\SupportingData\A_Demographic_data_bnb_update.xlsx', sheet_name = 'rename_columns_as')

# Create a dictionary to map current column names to updated column names
rename_dict = dict(zip(excel_data['Current_Name'], excel_data['Updated_Name']))

rename_dict
# Out:
# {'cust_id': 'cust_id',
#  'user_id': 'user_id',
#  'device_id': 'device_id',
#  'created_dt': 'created_dt',
#  'gender': 'de_gender',
#  'birthplace': 'de_birthplace',
#  'mobile_no': 'de_mobile_no',
#  'product': 'de_first_product',
#  'type': 'de_usage_type',
#  'telcoProvider': 'de_telco_provider',
#  'education_id': 'de_education_id',
#  'Education_Type': 'de_education_type',
#  'dateOfBirth': 'de_date_of_birth',
#  'signUpAccNo': 'de_sign_up_acc_no',
#  'kycStatus': 'de_kyc_status',
#  'addressline1': 'de_addressline1',
#  'city': 'de_city',
#  'province': 'de_province',
#  'barangay': 'de_barangay',
#  'provinceCode': 'de_province_code',
#  'postalcode': 'de_postal_code',
#  'mailingCity': 'de_mailing_city',
#  'mailingPostalCode': 'de_mailing_postal_code',
#  'mailingProvince': 'de_mailing_province',
#  'natureofwork': 'de_nature_of_work',
#  'employmentstatus': 'de_employment_status',
#  'mobileOs': 'de_mobile_os',
#  'docType': 'de_doc_type',
#  'onboardingDate': 'de_onboarding_date',
#  'Minutestakentoonboard': 'de_time_to_onboard_mins',
#  'companyName': 'de_company_name',
#  'industry': 'de_industry',
#  'device_dtl': 'de_device_dtl',
#  'Age': 'de_age',
#  'Region_Name': 'de_region_name',
#  'Onboarding_latitude': 'de_onboarding_lat',
#  'Onboarding_longitude': 'de_onboarding_long',
#  'loanjourney_latitude': 'de_loan_journey_lat',
#  'loanjouney_longitude': 'de_loan_jouney_long',
#  'ApigeeLogs_latitude': 'de_apigee_logs_lat',
#  'ApigeeLogs_longitude': 'de_apigee_logs_long',
#  'maritalStatus': 'de_marital_status',
#  'dependentsCount': 'de_dependents_cnt',
#  'monthlyIncome': 'de_monthly_income',
#  'startApplyDateTime': 'de_start_apply_date_time',
#  'network_group': 'de_network_group',
#  'Source': 'de_source',
#  'media_source': 'de_media_source',
#  'partner': 'de_partner',
#  'campaign': 'de_acq_campaign',
#  'earliest_date': 'de_earliest_date',
#  'months_difference': 'de_months_difference',
#  'DataSet': 'de_dataSet'}

# %% [markdown]
# ## Rename the column as per A_Demographic_data_bnb_update Excel Sheet

# %%
# Rename columns in the DataFrame 'res'
res.rename(columns=rename_dict, inplace=True)
res.columns
# Out:
# Index(['cust_id', 'user_id', 'device_id', 'created_dt', 'de_gender',
#        'de_birthplace', 'de_mobile_no', 'de_first_product', 'de_usage_type',
#        'de_telco_provider', 'de_education_id', 'de_education_type',
#        'de_date_of_birth', 'de_sign_up_acc_no', 'de_kyc_status',
#        'de_addressline1', 'de_city', 'de_province', 'de_barangay',
#        'de_province_code', 'de_postal_code', 'de_mailing_city',
#        'de_mailing_postal_code', 'de_mailing_province', 'de_nature_of_work',
#        'de_employment_status', 'de_mobile_os', 'de_doc_type',
#        'de_onboarding_date', 'de_time_to_onboard_mins', 'de_company_name',
#        'de_industry', 'de_device_dtl', 'de_age', 'de_region_name',
#        'de_onboarding_lat', 'de_onboarding_long', 'de_loan_journey_lat',
#        'de_loan_jouney_long', 'de_apigee_logs_lat', 'de_apigee_logs_long',
#        'de_marital_status', 'de_dependents_cnt', 'de_monthly_income',
#        'de_start_apply_date_time', 'de_network_group', 'de_source',
#        'de_media_source', 'de_partner', 'de_acq_campaign', 'SourceGroups',
#        'de_earliest_date', 'de_months_difference', 'onboardedDate'],
#       dtype='object')

# %% [markdown]
# ## Reshape the Column Position in DataFrame "Res"

# %%
res = res[['onboardedDate','cust_id', 'user_id', 'device_id', 'created_dt', 'de_gender',
       'de_birthplace', 'de_mobile_no', 'de_first_product', 'de_usage_type',
       'de_telco_provider', 'de_education_id', 'de_education_type',
       'de_date_of_birth', 'de_sign_up_acc_no', 'de_kyc_status',
       'de_addressline1', 'de_city', 'de_province', 'de_barangay',
       'de_province_code', 'de_postal_code', 'de_mailing_city',
       'de_mailing_postal_code', 'de_mailing_province', 'de_nature_of_work',
       'de_employment_status', 'de_mobile_os', 'de_doc_type',
       'de_onboarding_date', 'de_time_to_onboard_mins', 'de_company_name',
       'de_industry', 'de_device_dtl', 'de_age', 'de_region_name',
       'de_onboarding_lat', 'de_onboarding_long', 'de_loan_journey_lat',
       'de_loan_jouney_long', 'de_apigee_logs_lat', 'de_apigee_logs_long',
       'de_marital_status', 'de_dependents_cnt', 'de_monthly_income',
       'de_start_apply_date_time', 'de_network_group', 'de_source',
       'de_media_source', 'de_partner', 'de_acq_campaign', 'SourceGroups',
       'de_earliest_date', 'de_months_difference']].copy()

# %% [markdown]
# ## Create CSV file with new Column name

# %%
res.to_csv(r"C:\Users\DwaipayanChakroborti\OneDrive - Tonik Financial Pte Ltd\MyStuff\Biswa\Customer_360_Data_Prep\Data\Demographic_Daily_Snapshot_Data_renamedcolumn_20240909.csv", index = False)

# %%
res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 742699 entries, 0 to 1738
# Data columns (total 54 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   onboardedDate             742699 non-null  object
#  1   cust_id                   742699 non-null  int64
#  2   user_id                   742699 non-null  object
#  3   device_id                 742699 non-null  object
#  4   created_dt                742699 non-null  datetime64[us, UTC]
#  5   de_gender                 742699 non-null  object
#  6   de_birthplace             742699 non-null  object
#  7   de_mobile_no              742699 non-null  object
#  8   de_first_product          682841 non-null  object
#  9   de_usage_type             682841 non-null  object
#  10  de_telco_provider         573524 non-null  object
#  11  de_education_id           467068 non-null  object
#  12  de_education_type         467068 non-null  object
#  13  de_date_of_birth          742699 non-null  object
#  14  de_sign_up_acc_no         448582 non-null  object
#  15  de_kyc_status             742699 non-null  object
#  16  de_addressline1           742698 non-null  object
#  17  de_city                   742699 non-null  object
#  18  de_province               742699 non-null  object
#  19  de_barangay               742699 non-null  object
#  20  de_province_code          0 non-null       object
#  21  de_postal_code            742699 non-null  object
#  22  de_mailing_city           20936 non-null   object
#  23  de_mailing_postal_code    20936 non-null   object
#  24  de_mailing_province       20928 non-null   object
#  25  de_nature_of_work         742699 non-null  object
#  26  de_employment_status      742699 non-null  object
#  27  de_mobile_os              633126 non-null  object
#  28  de_doc_type               718087 non-null  object
#  29  de_onboarding_date        742699 non-null  datetime64[ns]
#  30  de_time_to_onboard_mins   742699 non-null  Int64
#  31  de_company_name           132788 non-null  object
#  32  de_industry               696331 non-null  object
#  33  de_device_dtl             313194 non-null  object
#  34  de_age                    742699 non-null  int64
#  35  de_region_name            742699 non-null  object
#  36  de_onboarding_lat         325596 non-null  object
#  37  de_onboarding_long        325596 non-null  object
#  38  de_loan_journey_lat       64515 non-null   object
#  39  de_loan_jouney_long       64515 non-null   object
#  40  de_apigee_logs_lat        351701 non-null  object
#  41  de_apigee_logs_long       351701 non-null  object
#  42  de_marital_status         671316 non-null  object
#  43  de_dependents_cnt         671132 non-null  object
#  44  de_monthly_income         680147 non-null  object
#  45  de_start_apply_date_time  671598 non-null  datetime64[us]
#  46  de_network_group          442 non-null     object
#  47  de_source                 443 non-null     object
#  48  de_media_source           26 non-null      object
#  49  de_partner                70 non-null      object
#  50  de_acq_campaign           89 non-null      object
#  51  SourceGroups              443 non-null     object
#  52  de_earliest_date          742699 non-null  datetime64[ns]
#  53  de_months_difference      742699 non-null  float64
# dtypes: Int64(1), datetime64[ns](2), datetime64[us, UTC](1), datetime64[us](1), float64(1), int64(2), object(46)
# memory usage: 312.4+ MB

# %%
res = rescopy.copy()

# %%
res.columns
# Out:
# Index(['onboardedDate', 'cust_id', 'user_id', 'device_id', 'created_dt',
#        'de_gender', 'de_birthplace', 'de_mobile_no', 'de_first_product',
#        'de_usage_type', 'de_telco_provider', 'de_education_id',
#        'de_education_type', 'de_date_of_birth', 'de_sign_up_acc_no',
#        'de_kyc_status', 'de_addressline1', 'de_city', 'de_province',
#        'de_barangay', 'de_province_code', 'de_postal_code', 'de_mailing_city',
#        'de_mailing_postal_code', 'de_mailing_province', 'de_nature_of_work',
#        'de_employment_status', 'de_mobile_os', 'de_doc_type',
#        'de_onboarding_date', 'de_time_to_onboard_mins', 'de_company_name',
#        'de_industry', 'de_device_dtl', 'de_age', 'de_region_name',
#        'de_onboarding_lat', 'de_onboarding_long', 'de_loan_journey_lat',
#        'de_loan_jouney_long', 'de_apigee_logs_lat', 'de_apigee_logs_long',
#        'de_marital_status', 'de_dependents_cnt', 'de_monthly_income',
#        'de_start_apply_date_time', 'de_network_group', 'de_source',
#        'de_media_source', 'de_partner', 'de_acq_campaign', 'SourceGroups',
#        'de_earliest_date', 'de_months_difference'],
#       dtype='object')

# %%
res1 = res[['onboardedDate', 'cust_id', 'user_id', 'device_id', 'created_dt',
       'de_gender', 'de_birthplace', 'de_mobile_no', 'de_first_product',
       'de_usage_type', 'de_telco_provider', 'de_date_of_birth', 'de_sign_up_acc_no',
       'de_kyc_status', 'de_addressline1', 'de_city', 'de_province',
       'de_barangay', 'de_province_code', 'de_postal_code', 'de_mailing_city',
       'de_mailing_postal_code', 'de_mailing_province', 'de_nature_of_work',
       'de_employment_status', 'de_mobile_os', 'de_doc_type',
       'de_onboarding_date', 'de_time_to_onboard_mins', 'de_company_name',
       'de_industry', 'de_device_dtl', 'de_age', 'de_region_name',
       'de_onboarding_lat', 'de_onboarding_long', 'de_loan_journey_lat',
       'de_loan_jouney_long', 'de_apigee_logs_lat', 'de_apigee_logs_long',
       'de_marital_status', 'de_dependents_cnt', 'de_monthly_income',
       'de_start_apply_date_time', 'de_network_group', 'de_source',
       'de_media_source', 'de_partner', 'de_acq_campaign', 'SourceGroups',
       'de_earliest_date', 'de_months_difference']].copy()

# %%
res1.shape
# Out:
# (742699, 52)

# %%
res1 = res1.drop_duplicates(keep='first')
res1.shape
# Out:
# (698470, 52)

# %%
res2 = res[['cust_id', 'de_education_id','de_education_type']].copy()

# %%
res2.shape
# Out:
# (742699, 3)

# %%
# Filtering rows with the max de_education_id for each cust_id
res2_filtered = res2[res2['de_education_id'] == res2.groupby('cust_id')['de_education_id'].transform('max')]
res2_filtered.shape
# Out:
# (459501, 3)

# %%
res2_filtered = res2_filtered.drop_duplicates(keep='first')
res2_filtered.shape
# Out:
# (423618, 3)

# %%
finaldata = res1.merge(res2_filtered, on = 'cust_id', how = 'left')
finaldata.shape
# Out:
# (698470, 54)

# %%
rescopy = res.copy()

# %%
duplicate_rows = finaldata[finaldata.duplicated('cust_id', keep=False)]

# %%
duplicate_rows['cust_id'].unique()
# Out:
# array([], dtype=int64)

# %%
finaldata[finaldata['cust_id'] == 1846420]
# Out:
#   onboardedDate  cust_id                           user_id  \
# 2    2023-01-01  1846420  3d5cfd27ae59498785e40c7c0a9bea58
#
#                                   device_id                created_dt  \
# 2  35dafe140e6644bb8551325866e62cb4iFvx32sI 2023-01-01 11:37:51+00:00
#
#   de_gender de_birthplace  de_mobile_no de_first_product de_usage_type  \
# 2         M   Santo tomas  639621306533             None          None
#
#   de_telco_provider de_date_of_birth de_sign_up_acc_no de_kyc_status  \
# 2              None      18 Jun 1985    60818464200009          SKYC
#
#                                      de_addressline1    de_city de_province  \
# 2  0470 JASMIN ST  PINEDA SUBD  DAU MABALACAT CIT...  MABALACAT    Pampanga
#
#   de_barangay de_province_code de_postal_code de_mailing_city  \
# 2         DAU             None           2010       MABALACAT
#
#   de_mailing_postal_code de_mailing_province de_nature_of_work  \
# 2                   2010            Pampanga                 6
#
#   de_employment_status de_mobile_os              de_doc_type  \
# 2                    1          iOS  Philippines - UMID Card
#
#    de_onboarding_date  de_time_to_onboard_mins        de_company_name  \
# 2 2023-01-01 11:37:51                       28  UPS International Inc
#
#   de_industry de_device_dtl  de_age              de_region_name  \
# 2           8    IOS-17.5.1      39  Region III – Central Luzon
#
#   de_onboarding_lat de_onboarding_long de_loan_journey_lat  \
# 2              None               None                None
#
#   de_loan_jouney_long  de_apigee_logs_lat de_apigee_logs_long  \
# 2                None  15.188132037168486  120.58662144614081
#
#   de_marital_status de_dependents_cnt de_monthly_income  \
# 2   Live-in Partner     No dependents             45000
#
#   de_start_apply_date_time de_network_group de_source de_media_source  \
# 2      2024-08-25 09:16:37              NaN       NaN             NaN
#
#   de_partner de_acq_campaign SourceGroups    de_earliest_date  \
# 2        NaN             NaN          NaN 2023-01-01 11:37:51
#
#    de_months_difference de_education_id de_education_type
# 2                 20.27              14  College Graduate

# %%
finaldata.columns
# Out:
# Index(['onboardedDate', 'cust_id', 'user_id', 'device_id', 'created_dt',
#        'de_gender', 'de_birthplace', 'de_mobile_no', 'de_first_product',
#        'de_usage_type', 'de_telco_provider', 'de_date_of_birth',
#        'de_sign_up_acc_no', 'de_kyc_status', 'de_addressline1', 'de_city',
#        'de_province', 'de_barangay', 'de_province_code', 'de_postal_code',
#        'de_mailing_city', 'de_mailing_postal_code', 'de_mailing_province',
#        'de_nature_of_work', 'de_employment_status', 'de_mobile_os',
#        'de_doc_type', 'de_onboarding_date', 'de_time_to_onboard_mins',
#        'de_company_name', 'de_industry', 'de_device_dtl', 'de_age',
#        'de_region_name', 'de_onboarding_lat', 'de_onboarding_long',
#        'de_loan_journey_lat', 'de_loan_jouney_long', 'de_apigee_logs_lat',
#        'de_apigee_logs_long', 'de_marital_status', 'de_dependents_cnt',
#        'de_monthly_income', 'de_start_apply_date_time', 'de_network_group',
#        'de_source', 'de_media_source', 'de_partner', 'de_acq_campaign',
#        'SourceGroups', 'de_earliest_date', 'de_months_difference',
#        'de_education_id', 'de_education_type'],
#       dtype='object')

# %%
finaldata = finaldata[['onboardedDate', 'cust_id', 'user_id', 'device_id', 'created_dt',
       'de_gender', 'de_birthplace', 'de_mobile_no', 'de_first_product',
       'de_usage_type', 'de_telco_provider', 'de_education_id', 'de_education_type', 'de_date_of_birth',
       'de_sign_up_acc_no', 'de_kyc_status', 'de_addressline1', 'de_city',
       'de_province', 'de_barangay', 'de_province_code', 'de_postal_code',
       'de_mailing_city', 'de_mailing_postal_code', 'de_mailing_province',
       'de_nature_of_work', 'de_employment_status', 'de_mobile_os',
       'de_doc_type', 'de_onboarding_date', 'de_time_to_onboard_mins',
       'de_company_name', 'de_industry', 'de_device_dtl', 'de_age',
       'de_region_name', 'de_onboarding_lat', 'de_onboarding_long',
       'de_loan_journey_lat', 'de_loan_jouney_long', 'de_apigee_logs_lat',
       'de_apigee_logs_long', 'de_marital_status', 'de_dependents_cnt',
       'de_monthly_income', 'de_start_apply_date_time', 'de_network_group',
       'de_source', 'de_media_source', 'de_partner', 'de_acq_campaign',
       'SourceGroups', 'de_earliest_date', 'de_months_difference']].copy()

# %%
finaldata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698470 entries, 0 to 698469
# Data columns (total 54 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   onboardedDate             698470 non-null  datetime64[ns]
#  1   cust_id                   698470 non-null  int64
#  2   user_id                   698470 non-null  object
#  3   device_id                 698470 non-null  object
#  4   created_dt                698470 non-null  datetime64[us, UTC]
#  5   de_gender                 698470 non-null  object
#  6   de_birthplace             698470 non-null  object
#  7   de_mobile_no              698470 non-null  object
#  8   de_first_product          640213 non-null  object
#  9   de_usage_type             640213 non-null  object
#  10  de_telco_provider         543654 non-null  object
#  11  de_education_id           423618 non-null  object
#  12  de_education_type         423618 non-null  object
#  13  de_date_of_birth          698470 non-null  object
#  14  de_sign_up_acc_no         413544 non-null  object
#  15  de_kyc_status             698470 non-null  object
#  16  de_addressline1           698469 non-null  object
#  17  de_city                   698470 non-null  object
#  18  de_province               698470 non-null  object
#  19  de_barangay               698470 non-null  object
#  20  de_province_code          0 non-null       object
#  21  de_postal_code            698470 non-null  object
#  22  de_mailing_city           16685 non-null   object
#  23  de_mailing_postal_code    16685 non-null   object
#  24  de_mailing_province       16678 non-null   object
#  25  de_nature_of_work         698470 non-null  object
#  26  de_employment_status      698470 non-null  object
#  27  de_mobile_os              591079 non-null  object
#  28  de_doc_type               673947 non-null  object
#  29  de_onboarding_date        698470 non-null  datetime64[ns]
#  30  de_time_to_onboard_mins   698470 non-null  Int64
#  31  de_company_name           98006 non-null   object
#  32  de_industry               652102 non-null  object
#  33  de_device_dtl             283561 non-null  object
#  34  de_age                    698470 non-null  int64
#  35  de_region_name            698470 non-null  object
#  36  de_onboarding_lat         323252 non-null  object
#  37  de_onboarding_long        323252 non-null  object
#  38  de_loan_journey_lat       60075 non-null   object
#  39  de_loan_jouney_long       60075 non-null   object
#  40  de_apigee_logs_lat        314265 non-null  object
#  41  de_apigee_logs_long       314265 non-null  object
#  42  de_marital_status         627253 non-null  object
#  43  de_dependents_cnt         627069 non-null  object
#  44  de_monthly_income         638118 non-null  object
#  45  de_start_apply_date_time  627532 non-null  datetime64[us]
#  46  de_network_group          371 non-null     object
#  47  de_source                 372 non-null     object
#  48  de_media_source           24 non-null      object
#  49  de_partner                64 non-null      object
#  50  de_acq_campaign           81 non-null      object
#  51  SourceGroups              372 non-null     object
#  52  de_earliest_date          698470 non-null  datetime64[ns]
#  53  de_months_difference      698470 non-null  float64
# dtypes: Int64(1), datetime64[ns](3), datetime64[us, UTC](1), datetime64[us](1), float64(1), int64(2), object(45)
# memory usage: 288.4+ MB

# %%
# sq = """drop table if exists worktable_data_analysis.customer_demographic_snapshot_data;"""
# client.query(sq)

# Convert 'onboardedDate' to a datetime format
res['onboardedDate'] = pd.to_datetime(res['onboardedDate'], errors='coerce')

# Define the dataset and table name
dataset_id = 'worktable_data_analysis'
table_id = 'customer_demographic_data'

# Define the schema based on the DataFrame structure
schema = [
    bigquery.SchemaField("onboardedDate", "TIMESTAMP"),  # Update to TIMESTAMP
    bigquery.SchemaField("cust_id", "INT64"),
    bigquery.SchemaField("user_id", "STRING"),
    bigquery.SchemaField("device_id", "STRING"),
    bigquery.SchemaField("created_dt", "TIMESTAMP"),
    bigquery.SchemaField("de_gender", "STRING"),
    bigquery.SchemaField("de_birthplace", "STRING"),
    bigquery.SchemaField("de_mobile_no", "STRING"),
    bigquery.SchemaField("de_first_product", "STRING"),
    bigquery.SchemaField("de_usage_type", "STRING"),
    bigquery.SchemaField("de_telco_provider", "STRING"),
    bigquery.SchemaField("de_education_id", "STRING"),
    bigquery.SchemaField("de_education_type", "STRING"),
    bigquery.SchemaField("de_date_of_birth", "STRING"),
    bigquery.SchemaField("de_sign_up_acc_no", "STRING"),
    bigquery.SchemaField("de_kyc_status", "STRING"),
    bigquery.SchemaField("de_addressline1", "STRING"),
    bigquery.SchemaField("de_city", "STRING"),
    bigquery.SchemaField("de_province", "STRING"),
    bigquery.SchemaField("de_barangay", "STRING"),
    bigquery.SchemaField("de_province_code", "STRING"),
    bigquery.SchemaField("de_postal_code", "STRING"),
    bigquery.SchemaField("de_mailing_city", "STRING"),
    bigquery.SchemaField("de_mailing_postal_code", "STRING"),
    bigquery.SchemaField("de_mailing_province", "STRING"),
    bigquery.SchemaField("de_nature_of_work", "STRING"),
    bigquery.SchemaField("de_employment_status", "STRING"),
    bigquery.SchemaField("de_mobile_os", "STRING"),
    bigquery.SchemaField("de_doc_type", "STRING"),
    bigquery.SchemaField("de_onboarding_date", "TIMESTAMP"),
    bigquery.SchemaField("de_time_to_onboard_mins", "INT64"),
    bigquery.SchemaField("de_company_name", "STRING"),
    bigquery.SchemaField("de_industry", "STRING"),
    bigquery.SchemaField("de_device_dtl", "STRING"),
    bigquery.SchemaField("de_age", "INT64"),
    bigquery.SchemaField("de_region_name", "STRING"),
    bigquery.SchemaField("de_onboarding_lat", "STRING"),
    bigquery.SchemaField("de_onboarding_long", "STRING"),
    bigquery.SchemaField("de_loan_journey_lat", "STRING"),
    bigquery.SchemaField("de_loan_jouney_long", "STRING"),
    bigquery.SchemaField("de_apigee_logs_lat", "STRING"),
    bigquery.SchemaField("de_apigee_logs_long", "STRING"),
    bigquery.SchemaField("de_marital_status", "STRING"),
    bigquery.SchemaField("de_dependents_cnt", "STRING"),
    bigquery.SchemaField("de_monthly_income", "STRING"),
    bigquery.SchemaField("de_start_apply_date_time", "TIMESTAMP"),
    bigquery.SchemaField("de_network_group", "STRING"),
    bigquery.SchemaField("de_source", "STRING"),
    bigquery.SchemaField("de_media_source", "STRING"),
    bigquery.SchemaField("de_partner", "STRING"),
    bigquery.SchemaField("de_acq_campaign", "STRING"),
    bigquery.SchemaField("SourceGroups", "STRING"),
    bigquery.SchemaField("de_earliest_date", "TIMESTAMP"),
    bigquery.SchemaField("de_months_difference", "FLOAT64")
]

# Create the dataset reference
dataset_ref = client.dataset(dataset_id)

# Define the table reference
table_ref = dataset_ref.table(table_id)

# Configure the job to overwrite the table if it already exists
job_config = bigquery.LoadJobConfig(schema=schema)

# Load the DataFrame into BigQuery
job = client.load_table_from_dataframe(finaldata, table_ref, job_config=job_config)

# Wait for the job to complete
job.result()

print(f"Table {table_id} created in dataset {dataset_id}.")
# Out:
# Table customer_demographic_data created in dataset worktable_data_analysis.

# %%
finaldata[finaldata['cust_id'] == 2297061]
# Out:
#        onboardedDate  cust_id                           user_id  \
# 334160    2023-11-07  2297061  6773680d603e4760bec72eeb937e756c
#
#                                        device_id                created_dt  \
# 334160  9e34a152e8204209b532d70ad0ca6f88p5f9rC5u 2023-11-07 12:03:50+00:00
#
#        de_gender           de_birthplace  de_mobile_no de_first_product  \
# 334160         M  Bucal MaragondonCavite  639087228122          TSAE1.0
#
#        de_usage_type de_telco_provider de_education_id de_education_type  \
# 334160       Explore              None              14  College Graduate
#
#        de_date_of_birth de_sign_up_acc_no de_kyc_status  \
# 334160      06 Dec 2000    60822970610006          SKYC
#
#                                   de_addressline1     de_city de_province  \
# 334160  BUCAL III B  MARAGONDON  CAVITE  REGION 4  MARAGONDON      Cavite
#
#         de_barangay de_province_code de_postal_code de_mailing_city  \
# 334160  BUCAL III B             None           4112      MARAGONDON
#
#        de_mailing_postal_code de_mailing_province de_nature_of_work  \
# 334160                   4112              Cavite                 0
#
#        de_employment_status de_mobile_os                    de_doc_type  \
# 334160                    8          iOS  Philippines - Driving License
#
#         de_onboarding_date  de_time_to_onboard_mins de_company_name  \
# 334160 2023-11-07 12:03:50                        2            NONE
#
#        de_industry de_device_dtl  de_age            de_region_name  \
# 334160           0          None      23  Region IV-A – CALABARZON
#
#        de_onboarding_lat de_onboarding_long de_loan_journey_lat  \
# 334160              None               None                None
#
#        de_loan_jouney_long  de_apigee_logs_lat de_apigee_logs_long  \
# 334160                None  14.273879344145675  120.75503172997001
#
#        de_marital_status de_dependents_cnt de_monthly_income  \
# 334160            Single     No dependents             70000
#
#        de_start_apply_date_time de_network_group de_source de_media_source  \
# 334160      2024-08-16 17:34:32              NaN       NaN             NaN
#
#        de_partner de_acq_campaign SourceGroups    de_earliest_date  \
# 334160        NaN             NaN          NaN 2023-11-07 12:03:50
#
#         de_months_difference
# 334160                 10.09
